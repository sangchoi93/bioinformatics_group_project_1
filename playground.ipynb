# %%
import pandas as pd
import numpy as np
from scrape_pdb import pdb_parser
from utilities import pdb_utilities

pdb_parser = pdb_parser(1)
pdb_utilities = pdb_utilities(pdb_parser.df_atom, 
                              pdb_parser.df_helix, 
                              pdb_parser.df_sheet)
print(pdb_parser.df_atom[pdb_parser.df_atom['protein_name'] == '12AS'])
print(pdb_utilities.calculate_angle('12ASA', '327', 'psi'))
# Out:
# parsing first 1 proteins in cullpdb_pc30_res3.0_R1.0_d191017_chains18877.gz
# parsing 12ASA...
# Empty DataFrame
# Columns: [alt_loc, atom_name, chain_id, charge, element, iCode, occupancy, protein_name, record_name, res_name, res_seq, serial_number, tempFactor, x, y, z]
# Index: []
# 327.N's coordinate is (7.676, 37.032, 16.597)
# 327.CA's coordinate is (8.277, 37.91, 17.62)
# 327.C's coordinate is (9.497, 37.335, 18.322)
# 328.N's coordinate is (10.334, 38.237, 18.838)
# 155.402

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import importlib
import scrape_pdb
importlib.reload(scrape_pdb)

from scrape_pdb import pdb_parser
from utilities import pdb_utilities

# building helix torsion angle chartccc
pdb_parser = pdb_parser(10)
pdb_parser.print_stats()
# Out:
# parsing first 10 proteins in cullpdb_pc30_res3.0_R1.0_d191017_chains18877.gz
# completed parsing 0 pdbs
# # atoms:16745 # helices:74 # sheets: 56
# Process ForkPoolWorker-128:
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-126:
# Process ForkPoolWorker-129:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
# ...

# %%
# import utilities
importlib.reload(utilities)
from utilities import pdb_utilities

pdb_utilities = pdb_utilities(pdb_parser.df_atom, 
                              pdb_parser.df_helix, 
                              pdb_parser.df_sheet)
df_ram = pdb_utilities.build_ramachandran_helices()
# Out:
# atom not found! 19HCA 101 psi
# atom not found! 19HCA 102 psi
# atom not found! 19HCA 102 phi
# atom not found! 19HCA 103 psi
# atom not found! 19HCA 103 phi
# atom not found! 19HCA 104 phi
# atom not found! 19HCA 206 psi
# atom not found! 19HCA 206 phi
# atom not found! 19HCA 243 psi
# atom not found! 19HCA 243 phi

# %%
df_ram
# Out:
#      aa_seq_num          helix_type  helix_type_code      phi protein_name  \
# 0             5  right-handed alpha                1  -41.618        12ASA
# 1             6  right-handed alpha                1  -55.470        12ASA
# 2             7  right-handed alpha                1  -54.431        12ASA
# 3             8  right-handed alpha                1  -54.315        12ASA
# 4             9  right-handed alpha                1  -61.377        12ASA
# 5            10  right-handed alpha                1  -86.142        12ASA
# 6            11  right-handed alpha                1  -52.886        12ASA
# 7            12  right-handed alpha                1  -53.767        12ASA
# 8            13  right-handed alpha                1  -55.691        12ASA
# 9            14  right-handed alpha                1  -64.640        12ASA
# 10           15  right-handed alpha                1  -61.051        12ASA
# ...

# %%
pdb_utilities.plot_ramachandran(df_ram)

# %%
pdb_utilities.plot_ramachandran(pdb_utilities.build_ramachandran_aa('VAL'))

# %%
pdb_utilities.df_helix[['protein_name', 'helix_class', 'init_seq_num', 'end_seq_num']].values[0][0]
# Out:
# '12ASA'

# %%
l = [{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2}]

# %%
import json
pd.read_json(json.dumps(l))
# Out:
#     test  test2
# 0      1      2
# 1      1      2
# 2      1      2
# 3      1      2
# 4      1      2
# 5      1      2
# 6      1      2
# 7      1      2
# 8      1      2
# 9      1      2
# 10     1      2
# 11     1      2
# 12     1      2
# 13     1      2
# 14     1      2

# %%
json.dumps(pdb_utilities.df_helix)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
# 6      5
# 7      1
# 8      1
# 9      5
# 10     1
# 11     1
# 12     1
# 13     5
# 14     5
# 15     1
# 16     5
# 17     1
# 18     1
# 19     1
# 20     1
# 21     1
# 22     1
# 23     1
# 24     5
# 25     5
# 26     1
# 27     1
# 28     1
# 29     1
#       ..
# 763    1
# 764    1
# 765    1
# 766    5
# 767    1
# 768    1
# 769    1
# 770    1
# 771    1
# 772    1
# 773    1
# 774    1
# 775    5
# 776    1
# 777    1
# 778    1
# 779    1
# 780    1
# 781    1
# 782    1
# 783    1
# 784    1
# 785    1
# 786    1
# 787    1
# 788    1
# 789    1
# 790    1
# 791    1
# 792    1
# Name: helix_class, Length: 793, dtype: object

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import importlib
import scrape_pdb
importlib.reload(scrape_pdb)

from scrape_pdb import pdb_parser
from utilities import pdb_utilities

import time
now = time.time()
# building helix torsion angle chartccc
pdb_parser_all = pdb_parser()
pdb_parser_all.print_stats()
print('----------------{}s---------------'.format(time.time()-now))
# Out:
# parsing all pdb in cullpdb_pc30_res3.0_R1.0_d191017_chains18877.gz
# completed parsing 500 pdbs
# completed parsing 1000 pdbs
# completed parsing 1500 pdbs
# completed parsing 2000 pdbs
# completed parsing 2500 pdbs
# completed parsing 3000 pdbs
# completed parsing 3500 pdbs
# completed parsing 4000 pdbs
# completed parsing 4500 pdbs
# completed parsing 5000 pdbs
# completed parsing 5500 pdbs
# completed parsing 6000 pdbs
# completed parsing 6500 pdbs
# completed parsing 7000 pdbs
# completed parsing 7500 pdbs
# completed parsing 8000 pdbs
# completed parsing 8500 pdbs
# completed parsing 9000 pdbs
