# %% [markdown]
# ### import pandas as pd
# import numpy as np
# from matplotlib import pyplot as plt
# import importlib
# import scrape_pdb
# importlib.reload(scrape_pdb)
#
# from scrape_pdb import pdb_parser
# from utilities import pdb_utilities
#
# # building helix torsion angle chartccc
# pdb_parser = pdb_parser()
# pdb_parser.print_stats()

# %%
### import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import importlib
import scrape_pdb
importlib.reload(scrape_pdb)

from scrape_pdb import pdb_parser
from utilities import pdb_utilities

# building helix torsion angle chartccc
pdb_parser = pdb_parser(10)
pdb_parser.print_stats()
# Out:
# parsing first 10 proteins in cullpdb_pc30_res3.0_R1.0_d191017_chains18877.gz
# # atoms:16745 # helices:74 # sheets: 56

# %%
import utilities
importlib.reload(utilities)
from utilities import pdb_utilities

pdb_utilities = pdb_utilities(pdb_parser.df_atom, 
                              pdb_parser.df_helix, 
                              pdb_parser.df_sheet)
# df_ram = pdb_utilities.build_ramachandran_helices()

# %%
df_ram = pdb_utilities.build_ramachandran_helices()
print(len(df_ram))

# %%
def parse_row(row):
#     print(row)
#     print(row['atom_name'], row['x'])
    if row['atom_name'] == 'N':
        return row['x']
    else:
        return None
    
df_messing = pdb_parser.df_atom[pdb_parser.df_atom['atom_name'].isin(['N', 'CA', 'C','O'])]
df_messing['x_n'] = df_messing.apply(lambda row: parse_row(row), axis=1)
df_messing['y_n'] = df_messing.apply(lambda row: parse_row(row), axis=1)
df_messing['z_n'] = df_messing.apply(lambda row: parse_row(row), axis=1)
# df_messing['x_n'] = df_messing.apply(lambda row: parse_row(row), axis=1)

print(df_messing.head())
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#   alt_loc atom_name chain_id charge element iCode occupancy protein_name  \
# 0                 N        A              N             1.0        12ASA
# 1                CA        A              C             1.0        12ASA
# 2                 C        A              C             1.0        12ASA
# 3                 O        A              O             1.0        12ASA
# 5                 N        A              N             1.0        12ASA
#
#   record_name res_name res_seq serial_number tempFactor       x       y  \
# 0        ATOM      ALA       4             1      44.65  11.751  37.846
# 1        ATOM      ALA       4             2      30.68  12.501  39.048
# 2        ATOM      ALA       4             3      24.74   13.74  38.628
# 3        ATOM      ALA       4             4      25.59  14.207  37.495
# 5        ATOM      TYR       5             6      19.29  14.235  39.531
#
#         z     x_n     y_n     z_n
# 0  29.016  11.751  11.751  11.751
# 1  28.539    None    None    None
# 2  27.754    None    None    None
# 3   27.89    None    None    None
# 5  26.906  14.235  14.235  14.235
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
df_messing
# Out:
#       alt_loc atom_name chain_id charge element iCode occupancy protein_name  \
# 0                     N        A              N             1.0        12ASA
# 1                    CA        A              C             1.0        12ASA
# 2                     C        A              C             1.0        12ASA
# 3                     O        A              O             1.0        12ASA
# 5                     N        A              N             1.0        12ASA
# 6                    CA        A              C             1.0        12ASA
# 7                     C        A              C             1.0        12ASA
# 8                     O        A              O             1.0        12ASA
# 17                    N        A              N             1.0        12ASA
# 18                   CA        A              C             1.0        12ASA
# 19                    C        A              C             1.0        12ASA
# 20                    O        A              O             1.0        12ASA
# 25                    N        A              N             1.0        12ASA
# 26                   CA        A              C             1.0        12ASA
# 27                    C        A              C             1.0        12ASA
# 28                    O        A              O             1.0        12ASA
# 30                    N        A              N             1.0        12ASA
# 31                   CA        A              C             1.0        12ASA
# 32                    C        A              C             1.0        12ASA
# 33                    O        A              O             1.0        12ASA
# 39                    N        A              N             1.0        12ASA
# 40                   CA        A              C             1.0        12ASA
# 41                    C        A              C             1.0        12ASA
# 42                    O        A              O             1.0        12ASA
# 48                    N        A              N             1.0        12ASA
# 49                   CA        A              C             1.0        12ASA
# 50                    C        A              C             1.0        12ASA
# 51                    O        A              O             1.0        12ASA
# 59                    N        A              N             1.0        12ASA
# 60                   CA        A              C             1.0        12ASA
# ...       ...       ...      ...    ...     ...   ...       ...          ...
# 16684                 C        A              C             1.0        1A3AA
# 16685                 O        A              O             1.0        1A3AA
# 16690                 N        A              N             1.0        1A3AA
# 16691                CA        A              C             1.0        1A3AA
# 16692                 C        A              C             1.0        1A3AA
# 16693                 O        A              O             1.0        1A3AA
# 16699                 N        A              N             1.0        1A3AA
# 16700                CA        A              C             1.0        1A3AA
# 16701                 C        A              C             1.0        1A3AA
# 16702                 O        A              O             1.0        1A3AA
# 16707                 N        A              N             1.0        1A3AA
# 16708                CA        A              C             1.0        1A3AA
# 16709                 C        A              C             1.0        1A3AA
# 16710                 O        A              O             1.0        1A3AA
# 16715                 N        A              N             1.0        1A3AA
# 16716                CA        A              C             1.0        1A3AA
# 16717                 C        A              C             1.0        1A3AA
# 16718                 O        A              O             1.0        1A3AA
# 16720                 N        A              N             1.0        1A3AA
# 16721                CA        A              C             1.0        1A3AA
# 16722                 C        A              C             1.0        1A3AA
# 16723                 O        A              O             1.0        1A3AA
# 16724                 N        A              N             1.0        1A3AA
# 16725                CA        A              C             1.0        1A3AA
# 16726                 C        A              C             1.0        1A3AA
# 16727                 O        A              O             1.0        1A3AA
# 16735                 N        A              N             1.0        1A3AA
# 16736                CA        A              C             1.0        1A3AA
# 16737                 C        A              C             1.0        1A3AA
# 16738                 O        A              O             1.0        1A3AA
#
#       record_name res_name res_seq serial_number tempFactor        x       y  \
# 0            ATOM      ALA       4             1      44.65   11.751  37.846
# 1            ATOM      ALA       4             2      30.68   12.501  39.048
# 2            ATOM      ALA       4             3      24.74    13.74  38.628
# 3            ATOM      ALA       4             4      25.59   14.207  37.495
# 5            ATOM      TYR       5             6      19.29   14.235  39.531
# 6            ATOM      TYR       5             7       8.51   15.552   39.41
# 7            ATOM      TYR       5             8       6.11   16.616  38.913
# 8            ATOM      TYR       5             9      17.99   17.187  37.844
# 17           ATOM      ILE       6            18      14.56   16.789   39.63
# 18           ATOM      ILE       6            19      23.27   17.791  39.281
# 19           ATOM      ILE       6            20       8.08   17.598  37.844
# 20           ATOM      ILE       6            21       5.44   18.538   37.05
# 25           ATOM      ALA       7            26      16.52   16.368  37.519
# 26           ATOM      ALA       7            27        5.2   16.004  36.186
# 27           ATOM      ALA       7            28      12.19   16.371  35.097
# 28           ATOM      ALA       7            29      22.26   17.143  34.202
# 30           ATOM      LYS       8            31       9.25   15.825  35.211
# 31           ATOM      LYS       8            32       4.96   16.137  34.313
# 32           ATOM      LYS       8            33      11.71   17.626  34.197
# 33           ATOM      LYS       8            34        2.0   18.101  33.107
# 39           ATOM      GLN       9            40       9.09   18.356  35.312
# 40           ATOM      GLN       9            41       8.15   19.794  35.327
# 41           ATOM      GLN       9            42      17.33   20.558  34.436
# 42           ATOM      GLN       9            43      11.99   21.576  33.835
# 48           ATOM      ARG      10            49      17.16   20.058  34.382
# 49           ATOM      ARG      10            50      19.12   20.706  33.656
# 50           ATOM      ARG      10            51      26.12   20.295  32.189
# 51           ATOM      ARG      10            52      27.96   21.084  31.308
# 59           ATOM      GLN      11            60      12.87   19.058  31.934
# 60           ATOM      GLN      11            61       4.78   18.626  30.599
# ...           ...      ...     ...           ...        ...      ...     ...
# 16684        ATOM      LEU     141          1068      15.23  -12.382  30.697
# 16685        ATOM      LEU     141          1069      15.19  -11.517  31.456
# 16690        ATOM      GLU     142          1074      15.07  -12.808  29.626
# 16691        ATOM      GLU     142          1075      16.25  -12.297  29.293
# 16692        ATOM      GLU     142          1076      14.98  -10.841  28.868
# 16693        ATOM      GLU     142          1077      16.31   -10.02  29.261
# 16699        ATOM      LEU     143          1083       14.7  -10.483  28.051
# 16700        ATOM      LEU     143          1084      14.66   -9.105  27.573
# 16701        ATOM      LEU     143          1085      15.82   -8.117  28.676
# 16702        ATOM      LEU     143          1086      16.22   -6.929  28.575
# 16707        ATOM      LEU     144          1091      15.63   -8.583   29.72
# 16708        ATOM      LEU     144          1092      14.98     -7.7  30.816
# 16709        ATOM      LEU     144          1093      15.27   -7.909  32.034
# 16710        ATOM      LEU     144          1094      14.89   -7.305   33.07
# 16715        ATOM      ALA     145          1099      14.91   -8.658  31.928
# 16716        ATOM      ALA     145          1100       17.6   -8.895  33.098
# 16717        ATOM      ALA     145          1101      17.57   -7.668  33.522
# 16718        ATOM      ALA     145          1102      18.73   -7.576  34.667
# 16720        ATOM      GLY     146          1104      18.57   -6.661  32.661
# 16721        ATOM      GLY     146          1105      20.59   -5.456  32.991
# 16722        ATOM      GLY     146          1106      21.39   -4.439  33.773
# 16723        ATOM      GLY     146          1107       21.8   -3.403  34.175
# 16724        ATOM      ARG     147          1108      21.85   -4.706  34.013
# 16725        ATOM      ARG     147          1109      21.81   -3.768  34.739
# 16726        ATOM      ARG     147          1110      23.25   -3.474  36.121
# 16727        ATOM      ARG     147          1111      22.43   -4.392  36.762
# 16735        ATOM      LYS     148          1119      23.49   -2.216  36.547
# 16736        ATOM      LYS     148          1120      26.47   -1.815  37.835
# 16737        ATOM      LYS     148          1121      27.07   -1.235  38.785
# 16738        ATOM      LYS     148          1122       27.9   -0.674  38.303
#
#             z   x_n
# 0      29.016  None
# 1      28.539  None
# 2      27.754  None
# 3       27.89  None
# 5      26.906  None
# 6      26.282  None
# 7      27.263  None
# 8      27.068  None
# 17     28.369  None
# 18     29.375  None
# 19     29.863  None
# 20     29.854  None
# 25     30.261  None
# 26     30.742  None
# 27     29.741  None
# 28     30.049  None
# 30     28.535  None
# 31     27.425  None
# 32     27.104  None
# 33     26.798  None
# 39     27.173  None
# 40     26.885  None
# 41     27.845  None
# 42     27.497  None
# 48     29.069  None
# 49     30.141  None
# 50     30.141  None
# 51     30.497  None
# 59     29.727  None
# 60      29.34  None
# ...       ...   ...
# 16684  43.331  None
# 16685   43.76  None
# 16690  43.994  None
# 16691  45.313  None
# 16692  45.243  None
# 16693  46.074  None
# 16699  44.252  None
# 16700  44.143  None
# 16701  43.814  None
# 16702  44.122  None
# 16707  43.143  None
# 16708  42.763  None
# 16709  43.639  None
# 16710  43.344  None
# 16715  44.731  None
# 16716  45.586  None
# 16717  46.375  None
# atom not found! 1KSIA 6 phi
# atom not found! 1KYQA 2 phi
# atom not found! 1L0SA 27 phi
# atom not found! 1L8QA 156 phi
# atom not found! 1L8RA 191 phi
# atom not found! 1LFPA 99 phi
# atom not found! 1LJ8A 229 phi
# atom not found! 1LMLA 100 phi
# atom not found! 1LQSL 56 phi
# atom not found! 1LXJA 13 phi
# atom not found! 1M15A 2 phi
# atom not found! 1M5QA 97 phi
# atom not found! 1M6YA 13 phi
# atom not found! 1MJHA 3 phi
# atom not found! 1MJHA 66 phi
# atom not found! 1MKKA 14 phi
# atom not found! 1MNNA 33 phi
# atom not found! 1MPXA 586 phi
# atom not found! 1MQSA 284 phi

# %%
import pandas as pd
import numpy as np
import json
from scrape_pdb import pdb_parser
from matplotlib import pyplot as plt
from matplotlib import cm

def plot_ramachandran(df:pd.DataFrame, colorcode_by: str=''):
    plt.grid()
    plt.xlabel('psi')
    plt.ylabel('phi')
    if colorcode_by:
        classes = list(np.unique(df[colorcode_by]))
        colors = cm.rainbow(np.linspace(0, 1, len(classes)))
        for cl, c in zip(classes, colors):
            df_tmp = df[df[colorcode_by] == cl]
            plt.scatter(df_tmp['psi'], df_tmp['phi'], alpha=0.5, color=c)
        plt.legend(classes, loc='best')
    else:
        plt.scatter(df['psi'], df['phi'], alpha=0.5)

# %%
plot_ramachandran(df_ram, 'helix_type')

# %%
plot_ramachandran(df_ram, 'helix_class')

# %%
l = [{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2},{'test':1, 'test2':2}]

# %%
import json
pd.read_json(json.dumps(l))
# Out:
#     test  test2
# 0      1      2
# 1      1      2
# 2      1      2
# 3      1      2
# 4      1      2
# 5      1      2
# 6      1      2
# 7      1      2
# 8      1      2
# 9      1      2
# 10     1      2
# 11     1      2
# 12     1      2
# 13     1      2
# 14     1      2

# %%
json.dumps(pdb_utilities.df_helix)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
# 6      5
# 7      1
# 8      1
# 9      5
# 10     1
# 11     1
# 12     1
# 13     5
# 14     5
# 15     1
# 16     5
# 17     1
# 18     1
# 19     1
# 20     1
# 21     1
# 22     1
# 23     1
# 24     5
# 25     5
# 26     1
# 27     1
# 28     1
# 29     1
#       ..
# 763    1
# 764    1
# 765    1
# 766    5
# 767    1
# 768    1
# 769    1
# 770    1
# 771    1
# 772    1
# 773    1
# 774    1
# 775    5
# 776    1
# 777    1
# 778    1
# 779    1
# 780    1
# 781    1
# 782    1
# 783    1
# 784    1
# 785    1
# 786    1
# 787    1
# 788    1
# 789    1
# 790    1
# 791    1
# 792    1
# Name: helix_class, Length: 793, dtype: object

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import importlib
import scrape_pdb
importlib.reload(scrape_pdb)

from scrape_pdb import pdb_parser
from utilities import pdb_utilities

import time
now = time.time()
# building helix torsion angle chartccc
pdb_parser_all = pdb_parser()
pdb_parser_all.print_stats()
print('----------------{}s---------------'.format(time.time()-now))
# Out:
# parsing all pdb in cullpdb_pc30_res3.0_R1.0_d191017_chains18877.gz
# completed parsing 500 pdbs
# completed parsing 1000 pdbs
# completed parsing 1500 pdbs
# completed parsing 2000 pdbs
# completed parsing 2500 pdbs
# completed parsing 3000 pdbs
# completed parsing 3500 pdbs
# completed parsing 4000 pdbs
# completed parsing 4500 pdbs
# completed parsing 5000 pdbs
# completed parsing 5500 pdbs
# completed parsing 6000 pdbs
# completed parsing 6500 pdbs
# completed parsing 7000 pdbs
# completed parsing 7500 pdbs
# completed parsing 8000 pdbs
# completed parsing 8500 pdbs
# completed parsing 9000 pdbs
